# %%
import os
import json
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from collections import defaultdict

# Path to the corpus
corpus_path = 'corpus_finished'

# Load the data
corpus = []
genders = []
categories = []
for filename in os.listdir(corpus_path):
    with open(os.path.join(corpus_path, filename), 'r') as f:
        try:
            poem = json.load(f)
            lines = poem.get('poem', {})
            text = ' '.join(line['text'] for line in lines.values())
            gender = poem.get('gender')
            category = poem.get('categories', [None])[0]  # Take the first category, if it exists
            if text and gender and category:  # Ensure all fields exist
                corpus.append(text)
                genders.append(gender)
                categories.append(category)
        except json.JSONDecodeError:
            print(f"Couldn't decode JSON from file: {filename}")

# Create the TF-IDF matrix
tfidf_vectorizer = TfidfVectorizer()
X_tfidf = tfidf_vectorizer.fit_transform(corpus)

# Create the Count matrix
count_vectorizer = CountVectorizer()
X_count = count_vectorizer.fit_transform(corpus)

# Get the feature names (words) from the vectorizer
feature_names = tfidf_vectorizer.get_feature_names_out()

# Separate the data based on gender and category
documents_by_category = defaultdict(lambda: defaultdict(list))
for doc, gender, category in zip(X_tfidf, genders, categories):
    documents_by_category[category][gender].append(doc)

# Calculate the average TF-IDF scores and word frequencies for each gender within each category
average_scores_by_category = {}
word_frequencies_by_category = {}
for category, docs_by_gender in documents_by_category.items():
    average_scores_by_category[category] = {}
    word_frequencies_by_category[category] = {}
    for gender, docs in docs_by_gender.items():
        # Convert the list of sparse matrices to a single dense matrix
        docs = np.vstack([doc.toarray() for doc in docs])
        average_scores = np.mean(docs, axis=0)
        word_frequencies = np.sum(docs, axis=0)
        average_scores_by_category[category][gender] = average_scores
        word_frequencies_by_category[category][gender] = word_frequencies

# Print the results
for category, scores_by_gender in average_scores_by_category.items():
    print("Category:", category)
    for gender, scores in scores_by_gender.items():
        # Get the indices of the top 10 scores
        top_indices = np.argsort(scores)[::-1][:10]
        # Get the corresponding words and their frequencies
        top_words_and_frequencies = [(feature_names[i], word_frequencies_by_category[category][gender][i]) for i in top_indices]
        print("Top words and their frequencies for {} authors: {}".format(gender, top_words_and_frequencies))
# Out:
# Category: Leben & Beziehungen
# Top words and their frequencies for m authors: [('ich', 5.599531032203162), ('die', 4.290911554681375), ('und', 3.857597133711369), ('in', 2.8565699320638935), ('du', 2.764360362059125), ('wir', 2.642308961012641), ('der', 2.4935751885021844), ('sie', 2.330984454608119), ('nicht', 2.239624621666245), ('den', 1.9375295671117436)]
# Top words and their frequencies for w authors: [('die', 2.718079379451495), ('ich', 2.606431776808473), ('du', 2.230537810921422), ('und', 1.8185665026192557), ('der', 1.7066945460218266), ('wir', 1.6966232059055462), ('das', 1.5815613115183738), ('nicht', 1.5610204863971895), ('in', 1.3404664199976473), ('ein', 1.2090209809450512)]
# Category: Natur
# Top words and their frequencies for w authors: [('wir', 1.5780395548300532), ('den', 1.4085572745737045), ('die', 1.2040332759486474), ('der', 0.961244622773085), ('zwischen', 0.8381701803418332), ('in', 0.7292027766708999), ('auf', 0.6947865475208665), ('müde', 0.6809905738167101), ('schnee', 0.5987952383266243), ('über', 0.5961353546229285)]
# Top words and their frequencies for m authors: [('die', 2.6021363866648186), ('und', 1.9148190595084902), ('der', 1.7411348177056305), ('ich', 1.3974003300933586), ('den', 1.1774272833167554), ('das', 1.1501187723475583), ('auf', 1.1101079248887071), ('in', 0.9765984484064186), ('halb', 0.9144537486159611), ('im', 0.9117893922954954)]
# Category: Musik
# Top words and their frequencies for m authors: [('wir', 0.28796155109370125), ('weißen', 0.2820403281865939), ('regen', 0.253717083073888), ('trompeten', 0.2403624023599567), ('regentag', 0.2403624023599567), ('blüte', 0.2403624023599567), ('unternehmung', 0.2403624023599567), ('lied', 0.23304610754943378), ('fenster', 0.21946840862178485), ('der', 0.20325301692276837)]
# Top words and their frequencies for w authors: [('wir', 0.3253739771885771), ('der', 0.28023803930972535), ('laß', 0.24493220066521976), ('nervösen', 0.20308924283701638), ('rot', 0.1907646663965928), ('drei', 0.1907646663965928), ('das', 0.1759634514646215), ('und', 0.17385445496641977), ('den', 0.17021366100540575), ('unsere', 0.16955755331883698)]
# Category: Humoristische Poesie
# Top words and their frequencies for m authors: [('ich', 0.5300410457339265), ('ball', 0.4385900861913258), ('junge', 0.4239293130232985), ('und', 0.41156100179077326), ('der', 0.40749341817838364), ('ist', 0.3957673608326639), ('mensch', 0.39536527280772094), ('nicht', 0.3539915868208128), ('fehlte', 0.35264630276929526), ('bumke', 0.3122378035147444)]
# Category: Heimat
# Top words and their frequencies for m authors: [('als', 0.7292645779987446), ('der', 0.6233040623758138), ('die', 0.5604371002921937), ('das', 0.4787189180479664), ('kein', 0.39211692495033545), ('und', 0.3301453128163054), ('man', 0.32468418680690414), ('den', 0.3227640743916405), ('in', 0.3062423092087132), ('wo', 0.2968759455194628)]
# Top words and their frequencies for w authors: [('see', 0.20811801370131042), ('sah', 0.1833971759941146), ('sie', 0.17400847845712664), ('wurde', 0.1720630556658193), ('die', 0.16303963099963764), ('ort', 0.1560885102759828), ('er', 0.15556986707683446), ('weihnacht', 0.15112025806805524), ('schlüssel', 0.15112025806805524), ('brautstrümpfe', 0.15112025806805524)]
# Category: Poetologische Gedichte
# Top words and their frequencies for w authors: [('hand', 0.22890447672916062), ('zeichenmächtiger', 0.1988713135921958), ('flösst', 0.1988713135921958), ('nachtgrünen', 0.1988713135921958), ('gedanke', 0.1988713135921958), ('fetzen', 0.1988713135921958), ('flatternd', 0.1988713135921958), ('klartext', 0.1988713135921958), ('simmernden', 0.1988713135921958), ('äussere', 0.1988713135921958)]
# Top words and their frequencies for m authors: [('erst', 0.2902728863775435), ('hand', 0.20648091751633413), ('strophen', 0.17938981309999028), ('schluß', 0.17938981309999028), ('heben', 0.17938981309999028), ('wisse', 0.17938981309999028), ('leichthin', 0.17938981309999028), ('daktylus', 0.17938981309999028), ('bin', 0.1785432060809523), ('sie', 0.17705113318718751)]
# Category: Identität (Individuum)
# Top words and their frequencies for w authors: [('mission', 0.9869756568364865), ('und', 0.04080071276348832), ('rotblütlerin', 0.031583221018767565), ('reibst', 0.023687415764075674), ('vessel', 0.022018124021950893), ('auch', 0.019507897452909047), ('plane', 0.015791610509383783), ('schraubt', 0.015791610509383783), ('kummer', 0.015791610509383783), ('mitlife', 0.015791610509383783)]
# Top words and their frequencies for m authors: [('wenn', 0.5175600696240491), ('wyoming', 0.30445992206514483), ('zurückkehrte', 0.2029732813767632), ('die', 0.19907498186913672), ('zuneigung', 0.18866941531349865), ('wäre', 0.18532941349866114), ('wir', 0.14057377670524368), ('ein', 0.12783968608590088), ('eine', 0.10992291493053709), ('denkel', 0.1014866406883816)]
# Category: Mythologie
# Top words and their frequencies for w authors: [('müsli', 0.2895294191058528), ('zur', 0.15496218728111222), ('und', 0.1496111705452453), ('neuer', 0.1447647095529264), ('motten', 0.1447647095529264), ('brodeln', 0.1447647095529264), ('fleckig', 0.1447647095529264), ('pickt', 0.1447647095529264), ('kosen', 0.1447647095529264), ('feuchtfröhliches', 0.1447647095529264)]
# Category: Lyrik für Kinder
# Top words and their frequencies for w authors: [('einer', 0.9071163936985004), ('hat', 0.4629663119829044), ('und', 0.42779451030473986), ('mama', 0.41643040505399154), ('sehr', 0.40832228996993464), ('10', 0.3889591477504169), ('ich', 0.3775290537995517), ('stadt', 0.31832522771739413), ('dir', 0.3066325076626024), ('sterne', 0.30206065015018496)]
# Top words and their frequencies for m authors: [('zuhaus', 0.4503414775346343), ('die', 0.3511984204553903), ('gspür', 0.2933857473335524), ('bei', 0.2696762105883653), ('und', 0.25075166090852047), ('muaßt', 0.2347085978668419), ('sehn', 0.22964889807855549), ('bockstill', 0.22517073876731716), ('füssen', 0.22517073876731716), ('stühle', 0.22517073876731716)]
# Category: Stadt & städtisches Leben
# Top words and their frequencies for w authors: [('dieses', 0.3137737544683049), ('wien', 0.29923182659244624), ('sitzen', 0.27065072908677024), ('in', 0.23312962144434163), ('auf', 0.20214959167906427), ('gar', 0.1834029623343772), ('dieser', 0.16738835968870147), ('abgründen', 0.1609589599748072), ('stufen', 0.1609589599748072), ('käfrige', 0.1609589599748072)]
# Top words and their frequencies for m authors: [('die', 0.7723591301446728), ('archen', 0.4076542940740905), ('und', 0.3508417347560331), ('zeit', 0.3006936111942392), ('entschuldigen', 0.2410884004592534), ('hanna', 0.2410884004592534), ('decken', 0.2387550301610331), ('der', 0.23874441288150672), ('werden', 0.23717761950563776), ('zu', 0.22239157530016204)]
# Category: Erinnerung
# Top words and their frequencies for w authors: [('wir', 0.5101846807900188), ('versprich', 0.48823080577592987), ('mir', 0.2394107927332315), ('enkel', 0.2262094022519559), ('jodeln', 0.2262094022519559), ('anwachsenden', 0.2262094022519559), ('nützt', 0.2262094022519559), ('zwingen', 0.2262094022519559), ('briefe', 0.214706303938825), ('linde', 0.21026804795095802)]
# Top words and their frequencies for m authors: [('seinem', 0.2132386967097609), ('einem', 0.18419058008502068), ('denn', 0.15035759575364938), ('knisternden', 0.1404631288461841), ('gleitend', 0.1404631288461841), ('arbeitet', 0.1404631288461841), ('abendregen', 0.1404631288461841), ('nacktheit', 0.1404631288461841), ('vorplatz', 0.1404631288461841), ('teerpappe', 0.1404631288461841)]
# Category: Sprache
# Top words and their frequencies for w authors: [('wort', 0.2905166532805898), ('dich', 0.22678435798893162), ('ich', 0.21464595746979692), ('viersprachenlieder', 0.20762915776435728), ('violette', 0.20762915776435728), ('karpatenrücken', 0.20762915776435728), ('lädt', 0.20762915776435728), ('väterlich', 0.20762915776435728), ('kukuruzmilch', 0.20762915776435728), ('föhrenzapfen', 0.20762915776435728)]
# Category: Photographie & Film
# Top words and their frequencies for m authors: [('share', 0.2830160959087348), ('me', 0.26307147904996614), ('ich', 0.20614195742493202), ('usb', 0.18867739727248986), ('ändern', 0.18867739727248986), ('lass', 0.16594703212466083), ('schlaf', 0.13277361852474792), ('zu', 0.1025722236841635), ('und', 0.09749698786584154), ('zufall', 0.09433869863624493)]
# Category: Körper
# Top words and their frequencies for w authors: [('ich', 0.47932418563302304), ('du', 0.45057488594839323), ('es', 0.4118888923752259), ('wie', 0.4077468122279228), ('in', 0.39551030901269213), ('ist', 0.3912995752797198), ('gezweig', 0.368226077717301), ('hier', 0.35391733342408627), ('die', 0.3440905835613409), ('rücken', 0.3105399254039064)]
# Top words and their frequencies for m authors: [('eine', 0.23359266184365515), ('gespenstische', 0.21566508270773554), ('geliehene', 0.21566508270773554), ('fertiggemalt', 0.21566508270773554), ('bittere', 0.21566508270773554), ('kontraktion', 0.21566508270773554), ('traumlos', 0.21566508270773554), ('beschrieb', 0.21566508270773554), ('geflüster', 0.21566508270773554), ('zeitung', 0.21566508270773554)]
# Category: Traditionen
# Top words and their frequencies for m authors: [('gras', 0.21977679881264883), ('die', 0.21562754095994602), ('namen', 0.20297224110784218), ('benannt', 0.1832083114819058), ('vokale', 0.1832083114819058), ('ich', 0.17514580670464022), ('nenne', 0.17029731585066482), ('gehe', 0.14822582303646906), ('werden', 0.14389994404692383), ('leute', 0.12615433022227332)]
# Category: Serien / Zyklen
# Top words and their frequencies for m authors: [('das', 0.768318541287281), ('der', 0.43526981040597945), ('im', 0.42660923100490644), ('die', 0.3758989422385882), ('wo', 0.37381181281836645), ('noch', 0.3612316780021943), ('bewegung', 0.3533039506131314), ('märch', 0.3524893529619023), ('klart', 0.3524893529619023), ('spieglein', 0.3524893529619023)]
# Top words and their frequencies for w authors: [('man', 1.1837177811398352), ('die', 1.0922541392389797), ('und', 0.8680290003096287), ('sich', 0.7890225329980494), ('donau', 0.7333195651117843), ('der', 0.7250635203880615), ('als', 0.6070520971252957), ('aus', 0.6035096510856316), ('in', 0.59960501266165), ('sie', 0.5729794960401889)]
# Category: Religion / Spiritualität
# Top words and their frequencies for m authors: [('die', 0.40645971097650646), ('lupinen', 0.3046126476732337), ('wir', 0.29553906438110555), ('ich', 0.27182508043699594), ('sehen', 0.24888171968526226), ('müssen', 0.24660399999308918), ('den', 0.21101050629717172), ('starre', 0.20307509844882246), ('wald', 0.19793752422754496), ('sonne', 0.1945206576889759)]
# Category: Gesellschaft
# Top words and their frequencies for m authors: [('die', 0.5539656681017098), ('der', 0.5301927167675536), ('und', 0.5122054239555667), ('ist', 0.4302198416626241), ('sie', 0.401246157628785), ('so', 0.4011864557205834), ('svalbard', 0.3673476908414658), ('paem', 0.3480136018498097), ('aus', 0.3217148795934561), ('du', 0.3135448329260448)]
# Top words and their frequencies for w authors: [('polizist', 0.3227698869246802), ('hunger', 0.2611389830178304), ('jeder', 0.21776390684674873), ('angst', 0.21360653362450427), ('auch', 0.1993641450082666), ('wir', 0.1676562367123994), ('und', 0.16678781986538962), ('jagst', 0.1613849434623401), ('abels', 0.1613849434623401), ('ziert', 0.1613849434623401)]
# Category: Vater
# Top words and their frequencies for m authors: [('mir', 0.3854156910996719), ('ich', 0.30873155460819374), ('ging', 0.2819444892145238), ('zu', 0.25948503717892213), ('und', 0.2365066635128612), ('daß', 0.2302980320861539), ('er', 0.1798948702602936), ('vaterwald', 0.17103626818358786), ('seiner', 0.16670924074873497), ('heut', 0.1589830567684488)]
# Category: Zeit
# Top words and their frequencies for w authors: [('die', 0.5333735974843355), ('das', 0.44934088499378744), ('der', 0.3807389610548799), ('was', 0.35239001482697646), ('und', 0.3263943794527388), ('des', 0.2828922991849587), ('wiegt', 0.27519263926037907), ('den', 0.27308250458733474), ('arm', 0.26709348715677417), ('wir', 0.26553003321565377)]
# Top words and their frequencies for m authors: [('zeit', 0.6083079992737822), ('holz', 0.39569578498174807), ('war', 0.3140226474361852), ('ordne', 0.2934499069403457), ('endlich', 0.24925423177272818), ('es', 0.2346404366774414), ('der', 0.2335750631206595), ('die', 0.20819349052983718), ('das', 0.2070188940432007), ('nie', 0.20565883988665148)]
# Category: Politische Lyrik
# Top words and their frequencies for m authors: [('und', 0.4465158359434305), ('die', 0.4457858972335097), ('sie', 0.30252464215018215), ('den', 0.24273826678489582), ('der', 0.23007153751658943), ('mestral', 0.17431473668316888), ('drunten', 0.1719801675423409), ('fur', 0.16203048611847992), ('in', 0.14228658804460453), ('war', 0.13725943663510412)]
# Category: Tod / Trauer
# Top words and their frequencies for w authors: [('die', 0.6413300418650952), ('wind', 0.42463162280267985), ('und', 0.4017404858282625), ('ist', 0.3755249889020078), ('weinst', 0.35905379101955487), ('donau', 0.3454675957886175), ('er', 0.3434619005960468), ('du', 0.3373742648076021), ('der', 0.30745670700365446), ('den', 0.29171887144168435)]
# Top words and their frequencies for m authors: [('hockt', 0.3205413540780775), ('fuhrwerk', 0.16027067703903874), ('geborstenen', 0.16027067703903874), ('unmerklich', 0.16027067703903874), ('füll', 0.16027067703903874), ('entfach', 0.16027067703903874), ('gestürzt', 0.16027067703903874), ('sinkt', 0.16027067703903874), ('erdsüchtig', 0.16027067703903874), ('herd', 0.16027067703903874)]
# Category: Spoken Word / Rap
# Top words and their frequencies for m authors: [('loop', 0.8669804001912809), ('häng', 0.42027546100182167), ('gibts', 0.3696439872304985), ('zum', 0.3516498593310299), ('die', 0.27840062860811826), ('und', 0.24308333036278568), ('also', 0.22659801807056645), ('deine', 0.21332119336379718), ('kram', 0.21013773050091084), ('dran', 0.21013773050091084)]
# Top words and their frequencies for w authors: [('und', 0.31703714766829083), ('butter', 0.2875941918668135), ('wir', 0.2323765719679195), ('orangenmarmelade', 0.19172946124454235), ('fladenbrot', 0.19172946124454235), ('zigaretten', 0.1782179659609184), ('die', 0.16924239922578108), ('mit', 0.163406825363108), ('oft', 0.14998308010881123), ('voller', 0.12935455948521243)]
# Category: Narrative Poesie
# Top words and their frequencies for w authors: [('der', 0.41859810106083356), ('die', 0.40015041835628246), ('ich', 0.396959569900345), ('und', 0.3707295361307659), ('einer', 0.34297045580476737), ('er', 0.27812932508933214), ('in', 0.27630207091524606), ('war', 0.25214622217636085), ('es', 0.2489571057303437), ('dem', 0.21650903616620304)]
# Category: Lautpoesie
# Top words and their frequencies for m authors: [('doch', 0.32474963905110105), ('ich', 0.3043985931538789), ('kann', 0.28030270363070353), ('mal', 0.25593177064780903), ('fragen', 0.2432422172538593), ('das', 0.21441772852652674), ('was', 0.20234757857840474), ('darf', 0.19459377380308743), ('tun', 0.1822741366612405), ('oder', 0.17339122503407126)]
# Category: Konkrete Poesie
# Top words and their frequencies for m authors: [('wieder', 0.611454898806247), ('immer', 0.6062205444853661), ('es', 0.37402085680185143), ('gelingt', 0.14325700835224567), ('frühling', 0.11698412536798004), ('verführt', 0.07705897910680941), ('gleicht', 0.07705897910680941), ('traut', 0.07705897910680941), ('stockt', 0.07705897910680941), ('hüllt', 0.07705897910680941)]
# Category: Experimentelle Poesie
# Top words and their frequencies for m authors: [('und', 0.5975947805746527), ('die', 0.37747305575884577), ('10', 0.24100441957387345), ('fortec', 0.2381291624932954), ('tüten', 0.2381291624932954), ('kg', 0.2381291624932954), ('16', 0.22134780278448296), ('von', 0.1904787078511469), ('der', 0.18161783351711203), ('blüten', 0.16048117740960513)]
# Category: Gesellschaftskritik
# Top words and their frequencies for w authors: [('die', 0.2869149252156523), ('uns', 0.28202677935322307), ('wir', 0.2334273106786663), ('und', 0.22083579694895397), ('tod', 0.2089448083184409), ('das', 0.18244532269521735), ('brombeerblätter', 0.17806842167207604), ('schütteln', 0.17806842167207604), ('sind', 0.17282866218327547), ('aufgegebene', 0.16533966602373087)]
# Top words and their frequencies for m authors: [('kater', 0.20220543463302065), ('leider', 0.1778453182092916), ('außer', 0.1778453182092916), ('nein', 0.1493458089671255), ('der', 0.12704533553478387), ('uns', 0.12228095358898111), ('und', 0.10448745367390806), ('kurzem', 0.10110271731651033), ('beschützen', 0.10110271731651033), ('misstraue', 0.10110271731651033)]
# Category: Beziehungskonflikt
# Top words and their frequencies for m authors: [('dann', 0.20209763401945646), ('eine', 0.1954980880416213), ('noch', 0.1493561941895094), ('ich', 0.14790094106583726), ('unbedingt', 0.13537062014469364), ('basho', 0.13537062014469364), ('heiligsprechung', 0.13537062014469364), ('liebesgedicht', 0.13537062014469364), ('schlucht', 0.13537062014469364), ('beiseite', 0.13537062014469364)]
# Category: Architektur & Design
# Top words and their frequencies for m authors: [('durst', 0.3077655719583742), ('vers', 0.29121049215073114), ('widervers', 0.16554932322069418), ('mittagshitze', 0.16554932322069418), ('gesehn', 0.16554932322069418), ('felssturz', 0.16554932322069418), ('grüner', 0.16554932322069418), ('grautier', 0.16554932322069418), ('vogellaut', 0.16554932322069418), ('winterphantom', 0.16554932322069418)]
# Category: Schreiben (Gedichte)
# Top words and their frequencies for m authors: [('schreibe', 0.46334486995307606), ('zehn', 0.20490989585895142), ('füßen', 0.1783524174194532), ('händen', 0.15878046954173222), ('jeder', 0.14872815526807184), ('an', 0.14750629460510378), ('finger', 0.14588875704520454), ('hand', 0.12686810418154829), ('hast', 0.1236733926631942), ('wir', 0.11450567344463784)]
# Category: Erotische Poesie
# Top words and their frequencies for m authors: [('mich', 0.3237745329787426), ('deinen', 0.18084505352511565), ('ich', 0.14928000306898367), ('schütze', 0.1366328465865174), ('drink', 0.1366328465865174), ('empfehle', 0.1366328465865174), ('rocks', 0.1366328465865174), ('longdrink', 0.1366328465865174), ('kaltdunkel', 0.1366328465865174), ('anstatt', 0.1366328465865174)]
# Category: Popkultur
# Top words and their frequencies for m authors: [('antenne', 0.3899015335896717), ('wir', 0.20252640180554324), ('urknallspur', 0.19495076679483586), ('zitterte', 0.19495076679483586), ('wünschelrute', 0.19495076679483586), ('tonwechsel', 0.19495076679483586), ('mittelwellensender', 0.19495076679483586), ('radio', 0.19495076679483586), ('stundenlang', 0.18121226073014898), ('trafen', 0.18121226073014898)]
# Category: Reisen
# Top words and their frequencies for w authors: [('zeitigt', 0.22372478453319877), ('chaussee', 0.22372478453319877), ('gasthof', 0.22372478453319877), ('zerfallen', 0.22372478453319877), ('nimmt', 0.22372478453319877), ('eichenblätter', 0.22372478453319877), ('verkrallt', 0.22372478453319877), ('abgeräumt', 0.22372478453319877), ('schienen', 0.20795852539165466), ('genommen', 0.196772186508356)]
# Category: Mundart
# Top words and their frequencies for m authors: [('schnäll', 0.8446787443077607), ('go', 0.4958859933173135), ('chäller', 0.04445677601619793), ('hüsli', 0.04445677601619793), ('voruse', 0.04445677601619793), ('hälfe', 0.04445677601619793), ('migros', 0.04445677601619793), ('luege', 0.04445677601619793), ('dokter', 0.04445677601619793), ('poschte', 0.04445677601619793)]
# Category: Liebe
# Top words and their frequencies for m authors: [('dich', 0.18404359415730284), ('wenn', 0.16901679888956925), ('wir', 0.14919586383921932), ('schnaken', 0.14361509313734144), ('aufgegessen', 0.14361509313734144), ('mücken', 0.14361509313734144), ('brombeerhecken', 0.14361509313734144), ('schwitzt', 0.14361509313734144), ('besiegen', 0.14361509313734144), ('färbt', 0.14361509313734144)]
# Category: Geschichte
# Top words and their frequencies for w authors: [('du', 0.17824730661467425), ('jemand', 0.17426963336687543), ('krieg', 0.17424864227102693), ('baseball', 0.14858708173791804), ('kind', 0.14269756746950338), ('und', 0.133086641000535), ('der', 0.1244760190861553), ('nicht', 0.12116640046651483), ('bist', 0.12059630717098153), ('the', 0.12021530194259339)]
# Category: Familie
# Top words and their frequencies for m authors: [('gibt', 0.45294289435259844), ('wolken', 0.35621811200630665), ('es', 0.26544258474379784), ('und', 0.2113834334046151), ('die', 0.18237057064818052), ('schal', 0.17283813672377718), ('soldaten', 0.17283813672377718), ('fluss', 0.14114016820137978), ('den', 0.13794961211856838), ('wo', 0.13746997605026995)]
# Category: Dichtung
# Top words and their frequencies for m authors: [('wolken', 0.4869930952592479), ('die', 0.19634150954551138), ('der', 0.18966328581737152), ('du', 0.1715332045083936), ('spiel', 0.1491414739512871), ('des', 0.1335831580758508), ('wenn', 0.13088551809223914), ('von', 0.11694559614213898), ('mit', 0.09478577149875639), ('auf', 0.09431622397644558)]
# Category: Medizin & Naturwissenschaft
# Top words and their frequencies for m authors: [('mdein', 0.1866864651579264), ('und', 0.15434911264486098), ('kleine', 0.13137258551862713), ('nicht', 0.126862346389918), ('du', 0.12215558301179796), ('dieses', 0.12130900342585736), ('da', 0.11961990650707348), ('nur', 0.11211732692733763), ('stockende', 0.0933432325789632), ('phonetisch', 0.0933432325789632)]
